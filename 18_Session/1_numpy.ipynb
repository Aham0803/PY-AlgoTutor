# %%
print("this is python")
# Out:
# this is python

# %% [markdown]
# # This is markdown

# %% [markdown]
# ## this is sample code

# %% [markdown]
# this is third heading

# %%
print("this is python")
# Out:
# this is python

# %%
! pip install numpy
# Out:
# ...
#   Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl (12.5 MB)
# ...

# %%
import numpy as np

# %% [markdown]
# initialize the array with the help of numpy

# %%
arr = np.array([1,2,3])

print(arr)
# Out:
# [1 2 3]

# %%
arr = arr*2
print(arr)
# Out:
# [2 4 6]

# %%
arr.shape
# Out:
# (3,)

# %%
arr1 =np.array([[1,2,3,4,5],[2,3,4,5,6]])
print(arr1)
arr1.shape
# Out:
# [[1 2 3 4 5]
#  [2 3 4 5 6]]
# (2, 5)
